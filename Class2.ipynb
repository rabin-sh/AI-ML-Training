# %% [markdown]
# <a href="https://colab.research.google.com/github/rabin-sh/AI-ML-Training/blob/Class-2/Class2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import   seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-224bab41-3df1-4bf5-9153-2a4a99169624" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-224bab41-3df1-4bf5-9153-2a4a99169624">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_excel('cropyeld.xlsx')

# %%
data.head()
# Out:
#    Rain Fall (mm)  Fertilizer Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 0          1230.0        80.0         28          80.0            24.0
# 1           480.0        60.0         36          70.0            20.0
# 2          1250.0        75.0         29          78.0            22.0
# 3           450.0        65.0         35          70.0            19.0
# 4          1200.0        80.0         27          79.0            22.0
#
#    Potassium (K)  Yeild (Q/acre)
# 0           20.0            12.0
# 1           18.0             8.0
# 2           19.0            11.0
# 3           18.0             9.0
# 4           19.0            11.0

# %%
data.describe()
# Out:
#        Rain Fall (mm)  Fertilizer  Nitrogen (N)  Phosphorus (P)  \
# count       99.000000   99.000000     99.000000       99.000000
# mean       849.797980   67.808081     70.737374       21.131313
# std        400.042676   10.028202      6.677079        1.951695
# min        400.000000   50.000000     59.000000       18.000000
# 25%        450.000000   60.000000     65.000000       19.500000
# 50%       1150.000000   70.000000     71.000000       21.000000
# 75%       1237.500000   77.000000     77.000000       23.000000
# max       1300.000000   80.000000     80.000000       25.000000
#
#        Potassium (K)  Yeild (Q/acre)
# count      99.000000       99.000000
# mean       18.060606        9.050505
# std         1.817254        1.965902
# min        15.000000        5.500000
# 25%        16.000000        7.000000
# 50%        19.000000        9.000000
# 75%        19.000000       11.000000
# max        22.000000       12.000000

# %%
data.head()
# Out:
#    Rain Fall (mm)  Fertilizer Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 0          1230.0        80.0         28          80.0            24.0
# 1           480.0        60.0         36          70.0            20.0
# 2          1250.0        75.0         29          78.0            22.0
# 3           450.0        65.0         35          70.0            19.0
# 4          1200.0        80.0         27          79.0            22.0
#
#    Potassium (K)  Yeild (Q/acre)
# 0           20.0            12.0
# 1           18.0             8.0
# 2           19.0            11.0
# 3           18.0             9.0
# 4           19.0            11.0

# %%
data.tail(20)
# Out:
#      Rain Fall (mm)  Fertilizer Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 89            410.0        52.0         40          62.0            19.0
# 90           1225.0        75.0         28          75.0            23.0
# 91            460.0        60.0         39          60.0            20.0
# 92           1150.0        78.0         29          77.0            21.0
# 93            475.0        65.0         38          60.0            20.0
# 94           1250.0        77.0         28          78.0            23.0
# 95            425.0        60.0         39          65.0            19.0
# 96           1220.0        79.0         28          77.0            23.0
# 97            480.0        65.0         36          68.0            21.0
# 98           1230.0        80.0         28          80.0            24.0
# 99              NaN         NaN        NaN           NaN             NaN
# 100             NaN         NaN        NaN           NaN             NaN
# ...

# %%
nan_count = data.isnull().sum(axis=0)
nan_count
# Out:
# Rain Fall (mm)    10
# Fertilizer        10
# Temperatue         9
# Nitrogen (N)      10
# Phosphorus (P)    10
# Potassium (K)     10
# Yeild (Q/acre)    10
# dtype: int64

# %%
final=data.dropna(axis=0)
final.tail()
# Out:
#     Rain Fall (mm)  Fertilizer Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 94          1250.0        77.0         28          78.0            23.0
# 95           425.0        60.0         39          65.0            19.0
# 96          1220.0        79.0         28          77.0            23.0
# 97           480.0        65.0         36          68.0            21.0
# 98          1230.0        80.0         28          80.0            24.0
#
#     Potassium (K)  Yeild (Q/acre)
# 94           20.0             9.0
# 95           17.0             6.5
# 96           21.0            10.5
# 97           16.0             7.0
# 98           20.0            12.0

# %%
plt.boxplot(final["Rain Fall (mm)"])
plt.title('Box plot')
plt.show()

# %%
plt.boxplot(final["Temperatue"])
plt.title('Box plot')
plt.show()

# %%
plt.scatter(data["Rain Fall (mm)"],data["Yeild (Q/acre)"])
plt.title("scatter Plot")
plt.xlabel('x')
plt.ylabel("y")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.isnull(),cbar=True,cmap='binary')
plt.show()
